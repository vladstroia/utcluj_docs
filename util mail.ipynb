# %%
#used this file to interpret email data

# %%
import pandas as pd

df_mail = pd.read_csv('adrese_mail.csv', dtype=str)
df_mail.applymap(lambda x: x.strip() if isinstance(x, str) else x)

df = pd.read_csv('tabel_materii.csv', dtype=str)
df.applymap(lambda x: x.strip() if isinstance(x, str) else x)
# df_mail.applymap(lambda x: x.strip() if isinstance(x, str) else x)
# we have to create the context object for each row in the csv file
# Out:
#      an sem nrcrt                                    nume_disciplina  \
# 0     1   1     1                    Bazele cercetarii experimentale
# 1     1   1     1                    Bazele cercetarii experimentale
# 2     1   1     2  Sisteme si echipamente avansate utilizate in c...
# 3     1   1     2  Sisteme si echipamente avansate utilizate in c...
# 4     1   1     2  Sisteme si echipamente avansate utilizate in c...
# ...  ..  ..   ...                                                ...
# 1894  4   2    67               Proiectare asistata de calculator II
# 1895  4   2    68                  Elaborarea proiectului de diploma
# 1896  4   2    69               Practica pentru proiectul de diploma
# 1897  4   2    70                        Sustinere examen de diploma
# 1898  4   2   308                                      Voluntariat 8
#
#                                               nume_engl sapt   formapred  \
# ...

# %%
df["nrdisc"][0]
df["email"][2]
for i in range(20):
    # in if we have to check if the email address is empty
    if df["email"][i] == df["email"][i]:
        print(df["nrdisc"][i] , df["email"][i])
# Out:
# 1 Daniela.MARIAN@math.utcluj.ro
# 2 Violeta.Popescu@chem.utcluj.ro
# 3 Calin.Prica@stm.utcluj.ro>
# 4 sanda.bodea@auto.utcluj.ro
# 5 Vasile-Horea.Ile@math.utcluj.ro
# 6 Iulian.Lupea@mep.utcluj.ro
# 7 andrei.kiraly@auto.utcluj.ro

# %%
f = open("tabel_adrese_gasite.csv", "a")

for nume_disc in df["nume_disciplina"]:
    
    nume_disc = nume_disc.strip()
    for i in range(1,1312):
        if nume_disc in df_mail["nume_disciplina"][i].strip():
            if df_mail["email"][i] == df_mail["email"][i] :
                # print(nume_disc,",",df_mail["email"][i].strip())
                f.write(nume_disc + "---" + df_mail["email"][i].strip() + '\n')
                
f.close()

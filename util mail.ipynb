# %%
#used this file to interpret email data

# %%
import pandas as pd

df = pd.read_csv('adrese_mail.csv', dtype=str)
df.applymap(lambda x: x.strip() if isinstance(x, str) else x)

# we have to create the context object for each row in the csv file
# Out:
#                                               facultate  \
# 0     Facultatea de Autovehicule Rutiere, Mecatronic...
# 1     Facultatea de Autovehicule Rutiere, Mecatronic...
# 2     Facultatea de Autovehicule Rutiere, Mecatronic...
# 3     Facultatea de Autovehicule Rutiere, Mecatronic...
# 4     Facultatea de Autovehicule Rutiere, Mecatronic...
# ...                                                 ...
# 1308  Facultatea de Autovehicule Rutiere, Mecatronic...
# 1309  Facultatea de Autovehicule Rutiere, Mecatronic...
# 1310  Facultatea de Autovehicule Rutiere, Mecatronic...
# 1311  Facultatea de Autovehicule Rutiere, Mecatronic...
# 1312  Facultatea de Autovehicule Rutiere, Mecatronic...
#
#                                                    spec an semestru nrdisc  \
# 0             Inginerie Mecanica  - (MIAIA,SET,MFN)-lic  1        1      1
# 1             Inginerie Mecanica  - (MIAIA,SET,MFN)-lic  1        1      1
# 2             Inginerie Mecanica  - (MIAIA,SET,MFN)-lic  1        1      2
# 3             Inginerie Mecanica  - (MIAIA,SET,MFN)-lic  1        1      2
# 4             Inginerie Mecanica  - (MIAIA,SET,MFN)-lic  1        1      2
# ...                                                 ... ..      ...    ...
# 1308  Fiabilitatea si mentenanta sistemelor mecanice...  2        1     13
# 1309  Fiabilitatea si mentenanta sistemelor mecanice...  2        1     13
# 1310  Fiabilitatea si mentenanta sistemelor mecanice...  2        1   14.1
# 1311  Fiabilitatea si mentenanta sistemelor mecanice...  2        1   14.1
# 1312  Fiabilitatea si mentenanta sistemelor mecanice...  2        1     15
#
#                                       nume_disciplina nume_formapred  \
# 0                                  Analiza matematica           curs
# 1                                  Analiza matematica        seminar
# 2                                              Chimie           curs
# 3                                              Chimie      laborator
# 4                                              Chimie      laborator
# ...                                               ...            ...
# 1308   Mentenanta sistemelor de racire si climatizare        proiect
# 1309   Mentenanta sistemelor de racire si climatizare        seminar
# 1310  Auditarea si certificarea sistemelor energetice           curs
# 1311  Auditarea si certificarea sistemelor energetice        seminar
# 1312                   Etica si integritate academica           curs
#
#                                          nume_facultate  \
# 0              Facultatea de Automatica si Calculatoare
# 1              Facultatea de Automatica si Calculatoare
# 2     Facultatea de Ingineria Materialelor si a Medi...
# 3     Facultatea de Ingineria Materialelor si a Medi...
# 4     Facultatea de Ingineria Materialelor si a Medi...
# ...                                                 ...
# 1308  Facultatea de Autovehicule Rutiere, Mecatronic...
# 1309  Facultatea de Autovehicule Rutiere, Mecatronic...
# 1310  Facultatea de Autovehicule Rutiere, Mecatronic...
# 1311  Facultatea de Autovehicule Rutiere, Mecatronic...
# 1312  Facultatea de Autovehicule Rutiere, Mecatronic...
#
#                               nume_catedra nrpost nume_post     nume_acop  \
# 0                               Matematica     16     Conf.  plata cu ora
# 1                               Matematica     22      S.l.         norma
# 2                         Fizica si Chimie      2     Prof.         norma
# 3                         Fizica si Chimie      2     Prof.         norma
# 4                         Fizica si Chimie     18      S.l.  plata cu ora
# ...                                    ...    ...       ...           ...
# 1308                    Inginerie mecanica     36     Asis.  plata cu ora
# 1309                    Inginerie mecanica     36     Asis.  plata cu ora
# 1310                    Inginerie mecanica     26      S.l.  plata cu ora
# 1311                    Inginerie mecanica     22      S.l.  plata cu ora
# 1312  Autovehicule rutiere si transporturi     41      S.l.  plata cu ora
#
#      numesfunc numestitlu  nprof_sup        pprof_sup  \
# 0        S. l.   dr. mat.     Marian          Daniela
# 1        S. l.   dr. mat.     Marian          Daniela
# 2        Prof.     dr.ch.    Popescu          Violeta
# 3        Prof.     dr.ch.    Popescu          Violeta
# 4        Prof.     dr.ch.    Popescu          Violeta
# ...        ...        ...        ...              ...
# 1308     Prof.   dr. ing.  Ungureanu  Nicolae Stelian
# 1309     Prof.   dr. ing.  Ungureanu  Nicolae Stelian
# 1310     Conf.   dr. ing.  Unguresan   Paula Veronica
# 1311     Conf.   dr. ing.  Unguresan   Paula Veronica
# 1312     S. l.     dr.ec.     Sechel   Ioana Cristina
#
#                                 email
# 0       Daniela.MARIAN@math.utcluj.ro
# 1                                 NaN
# 2      Violeta.Popescu@chem.utcluj.ro
# 3                                 NaN
# 4                                 NaN
# ...                               ...
# 1308                              NaN
# 1309                              NaN
# 1310  Paula.Unguresan@termo.utcluj.ro
# 1311                              NaN
# 1312      Ioana.Sechel@auto.utcluj.ro
#
# [1313 rows x 17 columns]

# %%
df["nrdisc"][0]
df["email"][2]
for i in range(20):
    # in if we have to check if the email address is empty
    if df["email"][i] == df["email"][i]:
        print(df["nrdisc"][i] , df["email"][i])
# Out:
# 1 Daniela.MARIAN@math.utcluj.ro
# 2 Violeta.Popescu@chem.utcluj.ro
# 3 Calin.Prica@stm.utcluj.ro>
# 4 sanda.bodea@auto.utcluj.ro
# 5 Vasile-Horea.Ile@math.utcluj.ro
# 6 Iulian.Lupea@mep.utcluj.ro
# 7 andrei.kiraly@auto.utcluj.ro

# %%
type(3) == "int"
# Out:
# False
